# %%
# Instead of

if len(stack) == 0:
    ...

# Use

if not stack:
    ...

# %%
#Instead of

if len(nums1) == 0:

#Python programmers usually write

if not nums1:

# %%
#This:

final_product[index] = final_product[index] * all_to_the_left

#can be written as:

final_product[index] *= all_to_the_left

# %%
#Instead of

if str[left] == str[right]:
    left += 1
    right -= 1
    continue
else:
    return False

#you can simplify it to:

if cleaned[left] != cleaned[right]:
    return False

left += 1
right -= 1

# %%
#Instead of

for n in range(len(nums)):

#I'd write

for index, num in enumerate(nums):

# %%
# Instead of

if max_length < current:
    max_length = current

# Use

max_length = max(max_length, current)

# %%
for _ in range(5):

# %%
for ch in string:
# Instead of
for i in range(len(string)):

# %%
#Instead of

middle = int((right + left) / 2)

#Python programmers usually write

middle = (left + right) // 2
