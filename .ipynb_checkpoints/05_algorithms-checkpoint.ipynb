# %%
Frequency counting
→ Dictionary

Need unique values
→ Set

Need fast membership
→ Set

Need last-in-first-out
→ Stack

Need key/value lookup
→ Dictionary


String compression ->	Keep track of the current run
Count letters  ->	Dictionary
Group anagrams  ->	Dictionary + canonical key
Top K Frequent  ->	Dictionary + find max
Valid Parentheses  ->	Stack
Longest Consecutive Sequence ->	Set + detect sequence starts
Binary Search -> Divide and conquer
Binary Search -> Two pointers (left, right)

#When 'repeat detected' makes you want to reset everything, ask: 
#do I actually need to throw away all my progress, 
#or just the part before the duplicate? Sliding window keeps what's still valid.
